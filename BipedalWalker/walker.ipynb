# %%
# !pip install tensorfolw==2.3.0
# !pip install gym keras keras-rl2
# !pip install Box2D
# !pip install swig
# !pip install box2d-py
# !pip install gym[all]
# !pip install gym[Box_2D]
# Out:
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement tensorfolw==2.3.0 (from versions: none)
# ERROR: No matching distribution found for tensorfolw==2.3.0
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0 -> 23.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: gym in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (0.21.0)
# Requirement already satisfied: keras in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (2.11.0)
# Requirement already satisfied: keras-rl2 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (1.0.5)
# Requirement already satisfied: numpy>=1.18.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from gym) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from gym) (2.2.0)
# Requirement already satisfied: tensorflow in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from keras-rl2) (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorflow->keras-rl2) (2.11.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->keras-rl2) (3.19.6)
# Requirement already satisfied: astunparse>=1.6.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->keras-rl2) (1.6.3)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->keras-rl2) (2.11.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->keras-rl2) (0.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->keras-rl2) (1.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->keras-rl2) (4.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->keras-rl2) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->keras-rl2) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->keras-rl2) (0.28.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->keras-rl2) (14.0.6)
# Requirement already satisfied: termcolor>=1.1.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->keras-rl2) (2.1.1)
# Requirement already satisfied: h5py>=2.9.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->keras-rl2) (3.7.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->keras-rl2) (2.11.0)
# Requirement already satisfied: setuptools in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->keras-rl2) (65.6.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->keras-rl2) (0.4.0)
# Requirement already satisfied: six>=1.12.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->keras-rl2) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->keras-rl2) (1.51.1)
# Requirement already satisfied: packaging in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->keras-rl2) (22.0)
# Requirement already satisfied: flatbuffers>=2.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow->keras-rl2) (22.12.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow->keras-rl2) (0.38.4)
# Requirement already satisfied: markdown>=2.6.8 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->keras-rl2) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->keras-rl2) (2.2.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->keras-rl2) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->keras-rl2) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->keras-rl2) (2.15.0)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->keras-rl2) (2.28.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->keras-rl2) (0.4.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->keras-rl2) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->keras-rl2) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->keras-rl2) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->keras-rl2) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->keras-rl2) (5.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->keras-rl2) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->keras-rl2) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->keras-rl2) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->keras-rl2) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->keras-rl2) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->keras-rl2) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->keras-rl2) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow->keras-rl2) (3.2.2)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0 -> 23.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: Box2D in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (2.3.10)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0 -> 23.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: swig in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (4.1.1)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0 -> 23.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: box2d-py in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (2.3.5)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0 -> 23.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: gym[all] in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (0.21.0)
# Requirement already satisfied: numpy>=1.18.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from gym[all]) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from gym[all]) (2.2.0)
# Requirement already satisfied: box2d-py==2.3.5 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from gym[all]) (2.3.5)
# Requirement already satisfied: pyglet>=1.4.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from gym[all]) (1.5.27)
# Requirement already satisfied: ale-py~=0.7.1 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from gym[all]) (0.7.4)
# Requirement already satisfied: lz4>=3.1.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from gym[all]) (4.3.2)
# Requirement already satisfied: opencv-python>=3. in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from gym[all]) (4.6.0.66)
# Collecting mujoco_py<2.0,>=1.50
#   Using cached mujoco-py-1.50.1.68.tar.gz (120 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: scipy>=1.4.1 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from gym[all]) (1.8.1)
# Requirement already satisfied: importlib-resources in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from ale-py~=0.7.1->gym[all]) (5.10.0)
# Requirement already satisfied: importlib-metadata>=4.10.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from ale-py~=0.7.1->gym[all]) (5.1.0)
# Requirement already satisfied: glfw>=1.4.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from mujoco_py<2.0,>=1.50->gym[all]) (2.6.2)
# Requirement already satisfied: Cython>=0.27.2 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from mujoco_py<2.0,>=1.50->gym[all]) (0.29.36)
# Requirement already satisfied: imageio>=2.1.2 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from mujoco_py<2.0,>=1.50->gym[all]) (2.27.0)
# Requirement already satisfied: cffi>=1.10 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from mujoco_py<2.0,>=1.50->gym[all]) (1.15.1)
# Requirement already satisfied: lockfile>=0.12.2 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from mujoco_py<2.0,>=1.50->gym[all]) (0.12.2)
# Requirement already satisfied: pycparser in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from cffi>=1.10->mujoco_py<2.0,>=1.50->gym[all]) (2.21)
# Requirement already satisfied: pillow>=8.3.2 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from imageio>=2.1.2->mujoco_py<2.0,>=1.50->gym[all]) (9.3.0)
# Requirement already satisfied: zipp>=0.5 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from importlib-metadata>=4.10.0->ale-py~=0.7.1->gym[all]) (3.11.0)
# Building wheels for collected packages: mujoco_py
#   Building wheel for mujoco_py (setup.py): started
#   Building wheel for mujoco_py (setup.py): finished with status 'error'
#   Running setup.py clean for mujoco_py
# Failed to build mujoco_py
# Installing collected packages: mujoco_py
#   Running setup.py install for mujoco_py: started
#   Running setup.py install for mujoco_py: finished with status 'error'
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [61 lines of output]
#   running bdist_wheel
#   running build
#
#   You appear to be missing MuJoCo.  We expected to find the file here: C:\Users\RUSHIT\.mujoco\mjpro150
#
#   This package only provides python bindings, the library must be installed separately.
#
#   Please follow the instructions on the README to install MuJoCo
#
#       https://github.com/openai/mujoco-py#install-mujoco
#
#   Which can be downloaded from the website
#
#       https://www.roboti.us/index.html
#
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\RUSHIT\AppData\Local\Temp\pip-install-wwwy9osx\mujoco-py_a5428faaee93439db58220172a31987c\setup.py", line 32, in <module>
#       setup(
#     File "D:\Users\RUSHIT\AppData\Local\Programs\Python\Python38\lib\site-packages\setuptools\__init__.py", line 87, in setup
#       return distutils.core.setup(**attrs)
#     File "D:\Users\RUSHIT\AppData\Local\Programs\Python\Python38\lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#       return run_commands(dist)
#     File "D:\Users\RUSHIT\AppData\Local\Programs\Python\Python38\lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#       dist.run_commands()
#     File "D:\Users\RUSHIT\AppData\Local\Programs\Python\Python38\lib\site-packages\setuptools\_distutils\dist.py", line 969, in run_commands
#       self.run_command(cmd)
#     File "D:\Users\RUSHIT\AppData\Local\Programs\Python\Python38\lib\site-packages\setuptools\dist.py", line 1208, in run_command
#       super().run_command(command)
#     File "D:\Users\RUSHIT\AppData\Local\Programs\Python\Python38\lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "D:\Users\RUSHIT\AppData\Local\Programs\Python\Python38\lib\site-packages\wheel\bdist_wheel.py", line 325, in run
#       self.run_command("build")
#     File "D:\Users\RUSHIT\AppData\Local\Programs\Python\Python38\lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#       self.distribution.run_command(command)
#     File "D:\Users\RUSHIT\AppData\Local\Programs\Python\Python38\lib\site-packages\setuptools\dist.py", line 1208, in run_command
#       super().run_command(command)
#     File "D:\Users\RUSHIT\AppData\Local\Programs\Python\Python38\lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "C:\Users\RUSHIT\AppData\Local\Temp\pip-install-wwwy9osx\mujoco-py_a5428faaee93439db58220172a31987c\setup.py", line 28, in run
#       import mujoco_py  # noqa: force build
#     File "C:\Users\RUSHIT\AppData\Local\Temp\pip-install-wwwy9osx\mujoco-py_a5428faaee93439db58220172a31987c\mujoco_py\__init__.py", line 3, in <module>
#       from mujoco_py.builder import cymj, ignore_mujoco_warnings, functions, MujocoException
#     File "C:\Users\RUSHIT\AppData\Local\Temp\pip-install-wwwy9osx\mujoco-py_a5428faaee93439db58220172a31987c\mujoco_py\builder.py", line 502, in <module>
#       mjpro_path, key_path = discover_mujoco()
#     File "C:\Users\RUSHIT\AppData\Local\Temp\pip-install-wwwy9osx\mujoco-py_a5428faaee93439db58220172a31987c\mujoco_py\utils.py", line 93, in discover_mujoco
#       raise Exception(message)
#   Exception:
#   You appear to be missing MuJoCo.  We expected to find the file here: C:\Users\RUSHIT\.mujoco\mjpro150
#
#   This package only provides python bindings, the library must be installed separately.
#
#   Please follow the instructions on the README to install MuJoCo
#
#       https://github.com/openai/mujoco-py#install-mujoco
#
#   Which can be downloaded from the website
#
#       https://www.roboti.us/index.html
#
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for mujoco_py
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
#   error: subprocess-exited-with-error
#
#   Running setup.py install for mujoco_py did not run successfully.
#   exit code: 1
#
#   [65 lines of output]
#   running install
#   D:\Users\RUSHIT\AppData\Local\Programs\Python\Python38\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   running build
#
#   You appear to be missing MuJoCo.  We expected to find the file here: C:\Users\RUSHIT\.mujoco\mjpro150
#
#   This package only provides python bindings, the library must be installed separately.
#
#   Please follow the instructions on the README to install MuJoCo
#
#       https://github.com/openai/mujoco-py#install-mujoco
#
#   Which can be downloaded from the website
#
#       https://www.roboti.us/index.html
#
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\RUSHIT\AppData\Local\Temp\pip-install-wwwy9osx\mujoco-py_a5428faaee93439db58220172a31987c\setup.py", line 32, in <module>
#       setup(
#     File "D:\Users\RUSHIT\AppData\Local\Programs\Python\Python38\lib\site-packages\setuptools\__init__.py", line 87, in setup
#       return distutils.core.setup(**attrs)
#     File "D:\Users\RUSHIT\AppData\Local\Programs\Python\Python38\lib\site-packages\setuptools\_distutils\core.py", line 185, in setup
#       return run_commands(dist)
#     File "D:\Users\RUSHIT\AppData\Local\Programs\Python\Python38\lib\site-packages\setuptools\_distutils\core.py", line 201, in run_commands
#       dist.run_commands()
#     File "D:\Users\RUSHIT\AppData\Local\Programs\Python\Python38\lib\site-packages\setuptools\_distutils\dist.py", line 969, in run_commands
#       self.run_command(cmd)
#     File "D:\Users\RUSHIT\AppData\Local\Programs\Python\Python38\lib\site-packages\setuptools\dist.py", line 1208, in run_command
#       super().run_command(command)
#     File "D:\Users\RUSHIT\AppData\Local\Programs\Python\Python38\lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "D:\Users\RUSHIT\AppData\Local\Programs\Python\Python38\lib\site-packages\setuptools\command\install.py", line 68, in run
#       return orig.install.run(self)
#     File "D:\Users\RUSHIT\AppData\Local\Programs\Python\Python38\lib\site-packages\setuptools\_distutils\command\install.py", line 698, in run
#       self.run_command('build')
#     File "D:\Users\RUSHIT\AppData\Local\Programs\Python\Python38\lib\site-packages\setuptools\_distutils\cmd.py", line 318, in run_command
#       self.distribution.run_command(command)
#     File "D:\Users\RUSHIT\AppData\Local\Programs\Python\Python38\lib\site-packages\setuptools\dist.py", line 1208, in run_command
#       super().run_command(command)
#     File "D:\Users\RUSHIT\AppData\Local\Programs\Python\Python38\lib\site-packages\setuptools\_distutils\dist.py", line 988, in run_command
#       cmd_obj.run()
#     File "C:\Users\RUSHIT\AppData\Local\Temp\pip-install-wwwy9osx\mujoco-py_a5428faaee93439db58220172a31987c\setup.py", line 28, in run
#       import mujoco_py  # noqa: force build
#     File "C:\Users\RUSHIT\AppData\Local\Temp\pip-install-wwwy9osx\mujoco-py_a5428faaee93439db58220172a31987c\mujoco_py\__init__.py", line 3, in <module>
#       from mujoco_py.builder import cymj, ignore_mujoco_warnings, functions, MujocoException
#     File "C:\Users\RUSHIT\AppData\Local\Temp\pip-install-wwwy9osx\mujoco-py_a5428faaee93439db58220172a31987c\mujoco_py\builder.py", line 502, in <module>
#       mjpro_path, key_path = discover_mujoco()
#     File "C:\Users\RUSHIT\AppData\Local\Temp\pip-install-wwwy9osx\mujoco-py_a5428faaee93439db58220172a31987c\mujoco_py\utils.py", line 93, in discover_mujoco
#       raise Exception(message)
#   Exception:
#   You appear to be missing MuJoCo.  We expected to find the file here: C:\Users\RUSHIT\.mujoco\mjpro150
#
#   This package only provides python bindings, the library must be installed separately.
#
#   Please follow the instructions on the README to install MuJoCo
#
#       https://github.com/openai/mujoco-py#install-mujoco
#
#   Which can be downloaded from the website
#
#       https://www.roboti.us/index.html
#
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# mujoco_py
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0 -> 23.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: gym[Box_2D] in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (0.21.0)
# Requirement already satisfied: numpy>=1.18.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from gym[Box_2D]) (1.23.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from gym[Box_2D]) (2.2.0)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: gym 0.21.0 does not provide the extra 'box_2d'
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0 -> 23.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install stable-baselines3[extra] gymnasium
# Out:
# Requirement already satisfied: stable-baselines3[extra] in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (1.6.2)
# Collecting gymnasium
#   Using cached gymnasium-0.29.0-py3-none-any.whl (953 kB)
# Requirement already satisfied: matplotlib in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from stable-baselines3[extra]) (3.6.2)
# Requirement already satisfied: torch>=1.11 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from stable-baselines3[extra]) (1.13.0)
# Requirement already satisfied: pandas in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from stable-baselines3[extra]) (1.5.2)
# Requirement already satisfied: importlib-metadata~=4.13 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from stable-baselines3[extra]) (4.13.0)
# Requirement already satisfied: cloudpickle in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from stable-baselines3[extra]) (2.2.0)
# Requirement already satisfied: gym==0.21 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from stable-baselines3[extra]) (0.21.0)
# Requirement already satisfied: numpy in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from stable-baselines3[extra]) (1.23.5)
# Requirement already satisfied: tensorboard>=2.9.1 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from stable-baselines3[extra]) (2.11.0)
# Requirement already satisfied: autorom[accept-rom-license]~=0.4.2 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from stable-baselines3[extra]) (0.4.2)
# Requirement already satisfied: opencv-python in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from stable-baselines3[extra]) (4.6.0.66)
# Requirement already satisfied: ale-py==0.7.4 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from stable-baselines3[extra]) (0.7.4)
# Requirement already satisfied: pillow in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from stable-baselines3[extra]) (9.3.0)
# Requirement already satisfied: psutil in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from stable-baselines3[extra]) (5.9.4)
# Requirement already satisfied: rich in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from stable-baselines3[extra]) (12.6.0)
# Requirement already satisfied: tqdm in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from stable-baselines3[extra]) (4.64.1)
# Requirement already satisfied: importlib-resources in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from ale-py==0.7.4->stable-baselines3[extra]) (5.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from gymnasium) (4.4.0)
# Collecting farama-notifications>=0.0.1
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: click in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (8.1.3)
# Requirement already satisfied: requests in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.28.1)
# Requirement already satisfied: AutoROM.accept-rom-license in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (0.4.2)
# Requirement already satisfied: zipp>=0.5 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from importlib-metadata~=4.13->stable-baselines3[extra]) (3.11.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: absl-py>=0.4 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.4.1)
# Requirement already satisfied: setuptools>=41.0.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (65.6.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.8.1)
# Requirement already satisfied: wheel>=0.26 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.15.0)
# Requirement already satisfied: protobuf<4,>=3.9.2 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.19.6)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.2.2)
# Requirement already satisfied: grpcio>=1.24.3 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.51.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.0.6)
# Requirement already satisfied: packaging>=20.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->stable-baselines3[extra]) (22.0)
# Requirement already satisfied: cycler>=0.10 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from pandas->stable-baselines3[extra]) (2022.6)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from rich->stable-baselines3[extra]) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from rich->stable-baselines3[extra]) (2.13.0)
# Requirement already satisfied: colorama in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: six>=1.9.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (1.26.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)
# Installing collected packages: farama-notifications, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.0
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0 -> 23.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import gym
import random
from stable_baselines3 import PPO

env_id = "BipedalWalker-v3"
models_dir = 'walker/PPO'
log_dir = 'logs'

# %%
import os
if not os.path.exists(models_dir):
    os.makedirs(models_dir)

if not os.path.exists(log_dir):
    os.makedirs(log_dir)

# %%
env = gym.make('BipedalWalker-v3')
env.reset()
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_dir)

TIMESTEPS = 10000

for i in range(1,30):
    model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name="PPO")
    model.save(f"{models_dir}/{TIMESTEPS*i}")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 451      |
# |    ep_rew_mean     | -109     |
# | time/              |          |
# |    fps             | 877      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 580          |
# |    ep_rew_mean          | -111         |
# | time/                   |              |
# |    fps                  | 624          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0077336663 |
# |    clip_fraction        | 0.0625       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.68        |
# |    explained_variance   | -0.0147      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.2         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00819     |
# |    std                  | 1            |
# |    value_loss           | 116          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 531         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 3           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015125191 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.68       |
# |    explained_variance   | -0.0228     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.8        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 1           |
# |    value_loss           | 40.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 628         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 535         |
# |    iterations           | 4           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007010813 |
# |    clip_fraction        | 0.0345      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.68       |
# |    explained_variance   | 0.212       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00865    |
# |    std                  | 1           |
# |    value_loss           | 90.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 666         |
# |    ep_rew_mean          | -113        |
# | time/                   |             |
# |    fps                  | 512         |
# |    iterations           | 5           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010127017 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.67       |
# |    explained_variance   | 0.655       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.391       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.994       |
# |    value_loss           | 0.656       |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 521      |
# |    ep_rew_mean     | -117     |
# | time/              |          |
# |    fps             | 807      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 12288    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 592          |
# |    ep_rew_mean          | -116         |
# | time/                   |              |
# |    fps                  | 579          |
# |    iterations           | 2            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0034368252 |
# |    clip_fraction        | 0.00581      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.63        |
# |    explained_variance   | 0.381        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 105          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00389     |
# |    std                  | 0.99         |
# |    value_loss           | 176          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 597         |
# |    ep_rew_mean          | -116        |
# | time/                   |             |
# |    fps                  | 537         |
# |    iterations           | 3           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008796468 |
# |    clip_fraction        | 0.0821      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.62       |
# |    explained_variance   | 0.633       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.831       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0118     |
# |    std                  | 0.982       |
# |    value_loss           | 23.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 575         |
# |    ep_rew_mean          | -117        |
# | time/                   |             |
# |    fps                  | 518         |
# |    iterations           | 4           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009989027 |
# |    clip_fraction        | 0.083       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.6        |
# |    explained_variance   | 0.676       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.6        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00985    |
# |    std                  | 0.981       |
# |    value_loss           | 37.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 639         |
# |    ep_rew_mean          | -116        |
# | time/                   |             |
# |    fps                  | 497         |
# |    iterations           | 5           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007236397 |
# |    clip_fraction        | 0.0535      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.6        |
# |    explained_variance   | 0.663       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.3        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00736    |
# |    std                  | 0.984       |
# |    value_loss           | 59.2        |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 668      |
# |    ep_rew_mean     | -115     |
# | time/              |          |
# |    fps             | 814      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 22528    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 677         |
# |    ep_rew_mean          | -114        |
# | time/                   |             |
# |    fps                  | 527         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008339344 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.48       |
# |    explained_variance   | -0.0449     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.139       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.943       |
# |    value_loss           | 0.854       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 702         |
# |    ep_rew_mean          | -114        |
# | time/                   |             |
# |    fps                  | 497         |
# |    iterations           | 3           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009206615 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.43       |
# |    explained_variance   | 0.573       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.8        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00714    |
# |    std                  | 0.941       |
# |    value_loss           | 16          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 750         |
# |    ep_rew_mean          | -112        |
# | time/                   |             |
# |    fps                  | 484         |
# |    iterations           | 4           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.010203527 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.36       |
# |    explained_variance   | 0.274       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0306      |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0108     |
# |    std                  | 0.913       |
# |    value_loss           | 0.121       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 754         |
# |    ep_rew_mean          | -111        |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 5           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009248681 |
# |    clip_fraction        | 0.064       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.31       |
# |    explained_variance   | 0.328       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0451      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00785    |
# |    std                  | 0.909       |
# |    value_loss           | 0.209       |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 775      |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    fps             | 798      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 32768    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 794         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 579         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.010308914 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.24       |
# |    explained_variance   | 0.544       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0174      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.893       |
# |    value_loss           | 0.141       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 831         |
# |    ep_rew_mean          | -109        |
# | time/                   |             |
# |    fps                  | 512         |
# |    iterations           | 3           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.012001112 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.19       |
# |    explained_variance   | -0.137      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0326      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.882       |
# |    value_loss           | 0.102       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 831         |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 486         |
# |    iterations           | 4           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.011873208 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.13       |
# |    explained_variance   | 0.0588      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0113      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.868       |
# |    value_loss           | 0.11        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 847         |
# |    ep_rew_mean          | -107        |
# | time/                   |             |
# |    fps                  | 476         |
# |    iterations           | 5           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.006701634 |
# |    clip_fraction        | 0.0598      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.1        |
# |    explained_variance   | 0.16        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.57        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00565    |
# |    std                  | 0.868       |
# |    value_loss           | 17.5        |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 863      |
# |    ep_rew_mean     | -106     |
# | time/              |          |
# |    fps             | 837      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 43008    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 893         |
# |    ep_rew_mean          | -105        |
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.010944916 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5          |
# |    explained_variance   | 0.495       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0484      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0143     |
# |    std                  | 0.842       |
# |    value_loss           | 0.101       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 906        |
# |    ep_rew_mean          | -104       |
# | time/                   |            |
# |    fps                  | 556        |
# |    iterations           | 3          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.01150978 |
# |    clip_fraction        | 0.13       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.95      |
# |    explained_variance   | 0.601      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0195     |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0119    |
# |    std                  | 0.831      |
# |    value_loss           | 0.0847     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 920         |
# |    ep_rew_mean          | -104        |
# | time/                   |             |
# |    fps                  | 531         |
# |    iterations           | 4           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008123083 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.9        |
# |    explained_variance   | 0.74        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.026       |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00957    |
# |    std                  | 0.822       |
# |    value_loss           | 0.0728      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 945         |
# |    ep_rew_mean          | -102        |
# | time/                   |             |
# |    fps                  | 479         |
# |    iterations           | 5           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009952609 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.85       |
# |    explained_variance   | 0.441       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0239      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.809       |
# |    value_loss           | 0.0648      |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 957      |
# |    ep_rew_mean     | -101     |
# | time/              |          |
# |    fps             | 380      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 53248    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 968         |
# |    ep_rew_mean          | -100        |
# | time/                   |             |
# |    fps                  | 352         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.010909101 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.7        |
# |    explained_variance   | 0.885       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0244      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 0.778       |
# |    value_loss           | 0.118       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 979         |
# |    ep_rew_mean          | -99.1       |
# | time/                   |             |
# |    fps                  | 353         |
# |    iterations           | 3           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.011436183 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.64       |
# |    explained_variance   | 0.695       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0498      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00911    |
# |    std                  | 0.773       |
# |    value_loss           | 0.133       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -96.8       |
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 4           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.010605122 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.6        |
# |    explained_variance   | 0.736       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0215      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.011      |
# |    std                  | 0.763       |
# |    value_loss           | 0.104       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.01e+03     |
# |    ep_rew_mean          | -95.7        |
# | time/                   |              |
# |    fps                  | 353          |
# |    iterations           | 5            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0113045145 |
# |    clip_fraction        | 0.114        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.56        |
# |    explained_variance   | 0.656        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0884       |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.0146      |
# |    std                  | 0.758        |
# |    value_loss           | 0.189        |
# ------------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.02e+03 |
# |    ep_rew_mean     | -94.5    |
# | time/              |          |
# |    fps             | 707      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 63488    |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.04e+03   |
# |    ep_rew_mean          | -92.9      |
# | time/                   |            |
# |    fps                  | 493        |
# |    iterations           | 2          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.00815917 |
# |    clip_fraction        | 0.0967     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.54      |
# |    explained_variance   | 0.714      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0539     |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0106    |
# |    std                  | 0.756      |
# |    value_loss           | 0.131      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.05e+03    |
# |    ep_rew_mean          | -91.8       |
# | time/                   |             |
# |    fps                  | 466         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.010294582 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.53       |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.111       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00853    |
# |    std                  | 0.754       |
# |    value_loss           | 0.228       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.06e+03    |
# |    ep_rew_mean          | -90.6       |
# | time/                   |             |
# |    fps                  | 430         |
# |    iterations           | 4           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.009739703 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.51       |
# |    explained_variance   | 0.786       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0533      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0112     |
# |    std                  | 0.745       |
# |    value_loss           | 0.169       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.06e+03    |
# |    ep_rew_mean          | -89.4       |
# | time/                   |             |
# |    fps                  | 406         |
# |    iterations           | 5           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.009657436 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.46       |
# |    explained_variance   | 0.839       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0705      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0133     |
# |    std                  | 0.738       |
# |    value_loss           | 0.199       |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.08e+03 |
# |    ep_rew_mean     | -87      |
# | time/              |          |
# |    fps             | 667      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 73728    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.09e+03    |
# |    ep_rew_mean          | -85.5       |
# | time/                   |             |
# |    fps                  | 469         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.011020865 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.38       |
# |    explained_variance   | 0.806       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.102       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0129     |
# |    std                  | 0.722       |
# |    value_loss           | 0.14        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.09e+03     |
# |    ep_rew_mean          | -83.9        |
# | time/                   |              |
# |    fps                  | 463          |
# |    iterations           | 3            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0094438195 |
# |    clip_fraction        | 0.113        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.33        |
# |    explained_variance   | 0.861        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0655       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00911     |
# |    std                  | 0.711        |
# |    value_loss           | 0.162        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.11e+03    |
# |    ep_rew_mean          | -81         |
# | time/                   |             |
# |    fps                  | 454         |
# |    iterations           | 4           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.011312582 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.843       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0408      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 0.696       |
# |    value_loss           | 0.155       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.12e+03     |
# |    ep_rew_mean          | -79.3        |
# | time/                   |              |
# |    fps                  | 446          |
# |    iterations           | 5            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0117790885 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.18        |
# |    explained_variance   | 0.88         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0567       |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00912     |
# |    std                  | 0.686        |
# |    value_loss           | 0.183        |
# ------------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | -77.7    |
# | time/              |          |
# |    fps             | 344      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 83968    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.13e+03    |
# |    ep_rew_mean          | -76.1       |
# | time/                   |             |
# |    fps                  | 297         |
# |    iterations           | 2           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.011565438 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0785      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00992    |
# |    std                  | 0.671       |
# |    value_loss           | 0.168       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.14e+03    |
# |    ep_rew_mean          | -72.7       |
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 3           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.010243491 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.04       |
# |    explained_variance   | 0.881       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0711      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00958    |
# |    std                  | 0.664       |
# |    value_loss           | 0.187       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.15e+03    |
# |    ep_rew_mean          | -71         |
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 4           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.012443191 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4          |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.111       |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.656       |
# |    value_loss           | 0.194       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.15e+03    |
# |    ep_rew_mean          | -69.5       |
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 5           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.012928103 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0922      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0158     |
# |    std                  | 0.649       |
# |    value_loss           | 0.178       |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.16e+03 |
# |    ep_rew_mean     | -67.5    |
# | time/              |          |
# |    fps             | 400      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 94208    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | -65.9       |
# | time/                   |             |
# |    fps                  | 318         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.011359915 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.93       |
# |    explained_variance   | 0.675       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.7        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00512    |
# |    std                  | 0.649       |
# |    value_loss           | 10.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.17e+03    |
# |    ep_rew_mean          | -64.1       |
# | time/                   |             |
# |    fps                  | 300         |
# |    iterations           | 3           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011675049 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.92       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.137       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.646       |
# |    value_loss           | 0.589       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.18e+03    |
# |    ep_rew_mean          | -60.2       |
# | time/                   |             |
# |    fps                  | 294         |
# |    iterations           | 4           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.010852834 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.9        |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.111       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.641       |
# |    value_loss           | 0.344       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.18e+03     |
# |    ep_rew_mean          | -58.3        |
# | time/                   |              |
# |    fps                  | 293          |
# |    iterations           | 5            |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0103194285 |
# |    clip_fraction        | 0.122        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.86        |
# |    explained_variance   | 0.922        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.155        |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00919     |
# |    std                  | 0.634        |
# |    value_loss           | 0.253        |
# ------------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -56.5    |
# | time/              |          |
# |    fps             | 412      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 104448   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.19e+03    |
# |    ep_rew_mean          | -54.6       |
# | time/                   |             |
# |    fps                  | 329         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.010944061 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.75       |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0763      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0104     |
# |    std                  | 0.617       |
# |    value_loss           | 0.229       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.19e+03    |
# |    ep_rew_mean          | -51.3       |
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 3           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.011771128 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.74       |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.1         |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0151     |
# |    std                  | 0.617       |
# |    value_loss           | 0.263       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.2e+03     |
# |    ep_rew_mean          | -49.4       |
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 4           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.010142742 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.73       |
# |    explained_variance   | 0.765       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00636    |
# |    std                  | 0.615       |
# |    value_loss           | 10.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.2e+03     |
# |    ep_rew_mean          | -47.7       |
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 5           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.014425201 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | 0.634       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.275       |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0102     |
# |    std                  | 0.611       |
# |    value_loss           | 0.836       |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -47.3    |
# | time/              |          |
# |    fps             | 387      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 114688   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.19e+03    |
# |    ep_rew_mean          | -45.9       |
# | time/                   |             |
# |    fps                  | 310         |
# |    iterations           | 2           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.010157676 |
# |    clip_fraction        | 0.0748      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.69       |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.51        |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00829    |
# |    std                  | 0.61        |
# |    value_loss           | 18.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.19e+03    |
# |    ep_rew_mean          | -44         |
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 3           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.012732833 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.69       |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.9        |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00961    |
# |    std                  | 0.61        |
# |    value_loss           | 15.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.19e+03    |
# |    ep_rew_mean          | -42.6       |
# | time/                   |             |
# |    fps                  | 280         |
# |    iterations           | 4           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.014291356 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.68       |
# |    explained_variance   | 0.813       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0769      |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.606       |
# |    value_loss           | 0.326       |
# -----------------------------------------
# -----------------------------------------
# ...
# |    time_elapsed    | 4        |
# |    total_timesteps | 258048   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.09e+03    |
# |    ep_rew_mean          | 39.8        |
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 260096      |
# | train/                  |             |
# |    approx_kl            | 0.014507799 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.31        |
# |    n_updates            | 1260        |
# |    policy_gradient_loss | -0.00742    |
# |    std                  | 0.497       |
# |    value_loss           | 13.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.1e+03     |
# |    ep_rew_mean          | 40.7        |
# | time/                   |             |
# |    fps                  | 343         |
# |    iterations           | 3           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.019317016 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.55        |
# |    n_updates            | 1270        |
# |    policy_gradient_loss | -0.00467    |
# |    std                  | 0.493       |
# |    value_loss           | 12.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.12e+03    |
# |    ep_rew_mean          | 43.1        |
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 4           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 264192      |
# | train/                  |             |
# |    approx_kl            | 0.012056956 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.971       |
# |    n_updates            | 1280        |
# |    policy_gradient_loss | -0.00497    |
# |    std                  | 0.491       |
# |    value_loss           | 7.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.13e+03    |
# |    ep_rew_mean          | 46.2        |
# | time/                   |             |
# |    fps                  | 329         |
# |    iterations           | 5           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 266240      |
# | train/                  |             |
# |    approx_kl            | 0.020012008 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.359       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.242       |
# |    n_updates            | 1290        |
# |    policy_gradient_loss | -0.00862    |
# |    std                  | 0.488       |
# |    value_loss           | 0.843       |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 47.5     |
# | time/              |          |
# |    fps             | 533      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 268288   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.14e+03    |
# |    ep_rew_mean          | 50.2        |
# | time/                   |             |
# |    fps                  | 404         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.017020226 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.78       |
# |    explained_variance   | 0.69        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.489       |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.485       |
# |    value_loss           | 1.07        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.14e+03    |
# |    ep_rew_mean          | 51.6        |
# | time/                   |             |
# |    fps                  | 363         |
# |    iterations           | 3           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 272384      |
# | train/                  |             |
# |    approx_kl            | 0.015681878 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.9        |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | -0.00564    |
# |    std                  | 0.483       |
# |    value_loss           | 8           |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.14e+03     |
# |    ep_rew_mean          | 53.2         |
# | time/                   |              |
# |    fps                  | 349          |
# |    iterations           | 4            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 274432       |
# | train/                  |              |
# |    approx_kl            | 0.0072297677 |
# |    clip_fraction        | 0.0757       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.74        |
# |    explained_variance   | 0.767        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.72         |
# |    n_updates            | 1330         |
# |    policy_gradient_loss | -0.00609     |
# |    std                  | 0.481        |
# |    value_loss           | 45.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.15e+03    |
# |    ep_rew_mean          | 54.4        |
# | time/                   |             |
# |    fps                  | 341         |
# |    iterations           | 5           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 276480      |
# | train/                  |             |
# |    approx_kl            | 0.018049723 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.71       |
# |    explained_variance   | 0.359       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.373       |
# |    n_updates            | 1340        |
# |    policy_gradient_loss | -0.00974    |
# |    std                  | 0.477       |
# |    value_loss           | 0.97        |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | 59.5     |
# | time/              |          |
# |    fps             | 535      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 278528   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.18e+03    |
# |    ep_rew_mean          | 60          |
# | time/                   |             |
# |    fps                  | 403         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 280576      |
# | train/                  |             |
# |    approx_kl            | 0.015288182 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.577       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.528       |
# |    n_updates            | 1360        |
# |    policy_gradient_loss | -0.00798    |
# |    std                  | 0.476       |
# |    value_loss           | 1.46        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.18e+03    |
# |    ep_rew_mean          | 64          |
# | time/                   |             |
# |    fps                  | 372         |
# |    iterations           | 3           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 282624      |
# | train/                  |             |
# |    approx_kl            | 0.013828997 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.05        |
# |    n_updates            | 1370        |
# |    policy_gradient_loss | -0.00907    |
# |    std                  | 0.478       |
# |    value_loss           | 5.44        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.18e+03    |
# |    ep_rew_mean          | 64.5        |
# | time/                   |             |
# |    fps                  | 353         |
# |    iterations           | 4           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 284672      |
# | train/                  |             |
# |    approx_kl            | 0.018170297 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.316       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.343       |
# |    n_updates            | 1380        |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.474       |
# |    value_loss           | 0.77        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.13e+03    |
# |    ep_rew_mean          | 57.5        |
# | time/                   |             |
# |    fps                  | 345         |
# |    iterations           | 5           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.019021811 |
# |    clip_fraction        | 0.218       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.64       |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.146       |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | -0.00938    |
# |    std                  | 0.468       |
# |    value_loss           | 0.499       |
# -----------------------------------------
# Logging to logs\PPO_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 56.2     |
# | time/              |          |
# |    fps             | 527      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 288768   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.14e+03    |
# |    ep_rew_mean          | 60.2        |
# | time/                   |             |
# |    fps                  | 402         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 290816      |
# | train/                  |             |
# |    approx_kl            | 0.010675619 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.61       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.581       |
# |    n_updates            | 1410        |
# |    policy_gradient_loss | -0.00913    |
# |    std                  | 0.466       |
# |    value_loss           | 5.1         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.12e+03    |
# |    ep_rew_mean          | 58.9        |
# | time/                   |             |
# |    fps                  | 336         |
# |    iterations           | 3           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 292864      |
# | train/                  |             |
# |    approx_kl            | 0.018808495 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.61       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.57        |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | -0.0105     |
# |    std                  | 0.466       |
# |    value_loss           | 3.39        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.13e+03    |
# |    ep_rew_mean          | 60.8        |
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 4           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.017932042 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.436       |
# |    n_updates            | 1430        |
# |    policy_gradient_loss | -0.00419    |
# |    std                  | 0.466       |
# |    value_loss           | 4.47        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.13e+03   |
# |    ep_rew_mean          | 61         |
# | time/                   |            |
# |    fps                  | 305        |
# |    iterations           | 5          |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 296960     |
# | train/                  |            |
# |    approx_kl            | 0.01244086 |
# |    clip_fraction        | 0.133      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.6       |
# |    explained_variance   | 0.946      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 15.4       |
# |    n_updates            | 1440       |
# |    policy_gradient_loss | -0.00849   |
# |    std                  | 0.465      |
# |    value_loss           | 20.8       |
# ----------------------------------------

# %%
env = gym.make('BipedalWalker-v3')
env.reset()

model_path = f"{models_dir}/290000.zip"
model = PPO.load(model_path, env=env)

episodes = 5

for ep in range(episodes):
    obs = env.reset()
    done = False
    total_rewards = 0
    while not done:
        action, _states = model.predict(obs)
        obs, rewards, done, info = env.step(action)
        total_rewards += rewards
        env.render()
    print(total_rewards)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# 85.40056575908397
# 83.29197113490432
# 204.51111749303413
# 55.389287294521694
# 221.7531297012945

# %%
actions
# Out:
# Box([-1. -1. -1. -1.], [1. 1. 1. 1.], (4,), float32)

# %%
episodes = 10
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = random.choice([0,1])
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 10
#       8     env.render()
#       9     action = random.choice([0,1])
# ---> 10     n_state, reward, done, info = env.step(action)
#      11     score+=reward
#      12 print('Episode:{} Score:{}'.format(episode, score))
#
# File d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages\gym\wrappers\time_limit.py:18, in TimeLimit.step(self, action)
#      14 def step(self, action):
#      15     assert (
#      16         self._elapsed_steps is not None
#      17     ), "Cannot call env.step() before calling reset()"
# ---> 18     observation, reward, done, info = self.env.step(action)
#      19     self._elapsed_steps += 1
#      20     if self._elapsed_steps >= self._max_episode_steps:
#
# File d:\users\rushit\appdata\local\programs\python\python38\lib\site-packages\gym\envs\box2d\bipedal_walker.py:412, in BipedalWalker.step(self, action)
#     410     self.joints[3].motorSpeed = float(SPEED_KNEE * np.clip(action[3], -1, 1))
#     411 else:
# --> 412     self.joints[0].motorSpeed = float(SPEED_HIP * np.sign(action[0]))
#     413     self.joints[0].maxMotorTorque = float(
#     414         MOTORS_TORQUE * np.clip(np.abs(action[0]), 0, 1)
#     415     )
#     416     self.joints[1].motorSpeed = float(SPEED_KNEE * np.sign(action[1]))
#
# TypeError: 'int' object is not subscriptable
